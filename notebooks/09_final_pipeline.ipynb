# %%
from pathlib import Path

import joblib
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.utils.class_weight import compute_sample_weight

# %%
TRAIN_PATH = (
    Path("..")
    / "data"
    / "processed"
    / "train_windows.parquet"
)

TEST_PATH = (
    Path("..")
    / "data"
    / "processed"
    / "test_windows.parquet"
)

train_df = pd.read_parquet(TRAIN_PATH)
test_df = pd.read_parquet(TEST_PATH)

print("Training rows:", len(train_df))
print("Testing rows:", len(test_df))
# Out:
# Training rows: 7335
# Testing rows: 1577

# %%
columns_not_used_for_model = [
    "participant_id",
    "recording_id",
    "window_number",
    "start_time_ms",
    "end_time_ms",
    "fog"
]

feature_columns = [
    column
    for column in train_df.columns
    if column not in columns_not_used_for_model
]

X_train = train_df[feature_columns]
y_train = train_df["fog"]

X_test = test_df[feature_columns]
y_test = test_df["fog"]

print("Number of features:", len(feature_columns))
# Out:
# Number of features: 45

# %%
sample_weights = compute_sample_weight(
    class_weight="balanced",
    y=y_train
)

final_model = GradientBoostingClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    random_state=42
)

final_model.fit(
    X_train,
    y_train,
    sample_weight=sample_weights
)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
MODEL_PATH = (
    Path("..")
    / "models"
    / "final_gradient_boosting_model.joblib"
)

model_bundle = {
    "model": final_model,
    "feature_columns": feature_columns
}

joblib.dump(
    model_bundle,
    MODEL_PATH
)

print("Final model saved:", MODEL_PATH.exists())
# Out:
# Final model saved: True

# %%
model_bundle = joblib.load(MODEL_PATH)

saved_model = model_bundle["model"]
saved_feature_columns = model_bundle["feature_columns"]

# %%
def predict_windows(window_data):
    
    model_inputs = window_data[saved_feature_columns]

    predictions = saved_model.predict(model_inputs)

    prediction_report = window_data[
        [
            "participant_id",
            "recording_id",
            "window_number",
            "start_time_ms",
            "end_time_ms",
            "fog"
        ]
    ].copy()

    prediction_report["predicted_fog"] = predictions

    prediction_report["start_time_seconds"] = (
        prediction_report["start_time_ms"] / 1000
    )

    prediction_report["end_time_seconds"] = (
        prediction_report["end_time_ms"] / 1000
    )

    return prediction_report

# %%
prediction_report = predict_windows(test_df)

prediction_report.head()
# Out:
#   participant_id recording_id  window_number  start_time_ms  end_time_ms  fog  \
# 0            S02          R01              0         670000       671984    0
# 1            S02          R01              1         672000       673984    0
# 2            S02          R01              2         674000       675984    0
# 3            S02          R01              3         676000       677984    0
# 4            S02          R01              4         678000       679984    0
#
#    predicted_fog  start_time_seconds  end_time_seconds
# 0              0               670.0           671.984
# 1              0               672.0           673.984
# 2              0               674.0           675.984
# 3              0               676.0           677.984
# 4              0               678.0           679.984

# %%
one_recording = prediction_report[
    prediction_report["recording_id"]
    == prediction_report["recording_id"].iloc[0]
].copy()

plt.figure(figsize=(12, 4))

plt.step(
    one_recording["start_time_seconds"],
    one_recording["fog"],
    where="post",
    label="Actual FoG"
)

plt.step(
    one_recording["start_time_seconds"],
    one_recording["predicted_fog"],
    where="post",
    label="Predicted FoG"
)

plt.xlabel("Time (seconds)")
plt.ylabel("FoG status")
plt.title("Actual and predicted FoG windows")
plt.yticks([0, 1], ["No FoG", "FoG"])
plt.legend()
plt.grid(True)
plt.show()
